# %% [markdown]
# Data Mining

# %%
import numpy as np
import random
import pandas as pd
import copy
import matplotlib.pyplot as plt

# %%
#adjacency_df.columns=(range(1,(n+4)))
#adjacency_df=adjacency_df.rename(columns={n+1:'Threshold',n+2:'IsInfected', n+3:'IsRisky' },errors='raise')

# %%
node_features=pd.DataFrame(pd.read_csv("C:/Users/Lenovo/Desktop/node_features-n100-m400.csv"))
optimal_blocked_nodes=pd.read_csv("C:/Users/Lenovo/Desktop/Math_Model_NODE-n100-m400.0-OBJ13.0.csv")

# %%
df_for_dm=pd.concat([node_features,optimal_blocked_nodes],axis=1)
df_for_dm
# Out:
#     IsInfected  IsRisky  map_for_dict  Betweenness  Degree_Cent  \
# 0          0.0      0.0             0     0.003060     0.101010
# 1          0.0      0.0             1     0.006806     0.121212
# 2          0.0      0.0             2     0.007848     0.121212
# 3          0.0      1.0             3     0.014998     0.161616
# 4          0.0      0.0             4     0.014612     0.141414
# ..         ...      ...           ...          ...          ...
# 95         0.0      0.0            95     0.008302     0.161616
# 96         0.0      0.0            96     0.015295     0.141414
# 97         0.0      0.0            97     0.015468     0.202020
# 98         1.0      0.0            98     0.037369     0.222222
# 99         0.0      0.0            99     0.014745     0.181818
#
#     Closeness_cent  Eigenvector_cent  Degree  Shortest_to_Infected  \
# 0         0.386719          0.060591      10                     1
# ...

# %%
setP = df_for_dm.loc[(df_for_dm.loc[:, "IsInfected"] > 0),"IsInfected"].index.tolist()

# %%
df_for_dm.drop(setP,inplace=True)

# %%
df_for_dm.drop(['IsInfected','map_for_dict','Degree'],axis=1,inplace=True)

# %%
#df_for_dm.loc[df_for_dm.loc[:,'Blocked'] == 1,:]
ati = df_for_dm.loc[(df_for_dm.loc[:, "IsRisky"] < 1),"IsRisky"].index.tolist()

# %%
ati
# Out:
# [0,
#  1,
#  2,
#  4,
#  5,
#  6,
#  9,
#  10,
#  14,
#  15,
#  16,
#  17,
#  18,
#  19,
#  20,
#  23,
#  25,
#  26,
#  27,
#  28,
#  29,
#  30,
#  33,
#  34,
#  36,
#  37,
#  38,
#  39,
#  40,
#  41,
#  42,
#  44,
#  45,
#  46,
#  47,
#  48,
#  49,
#  50,
#  52,
#  53,
#  54,
#  56,
#  58,
#  59,
#  61,
#  63,
#  64,
#  66,
#  68,
#  69,
#  72,
#  73,
#  74,
#  75,
#  76,
#  78,
#  79,
#  82,
#  83,
#  86,
#  87,
#  89,
#  90,
#  91,
#  92,
#  95,
#  96,
#  97,
#  99]

# %%
df_for_dm.drop(ati,inplace=True)

# %%
df_for_dm.drop(['IsRisky','Shortest_to_Risky'],axis=1,inplace=True)

# %%
plt.matshow(df_for_dm.corr())
plt.show()

# %%
corr = df_for_dm.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_b63b6f46_9e23_11eb_8f8f_c85b7619e923row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b63b6f46_9e23_11eb_8f8f_c85b7619e923row0_col1 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_b63b6f46_9e23_11eb_8f8f_c85b7619e923row0_col2 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_b63b6f46_9e23_11eb_8f8f_c85b7619e923row0_col3 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_b63b6f46_9e23_11eb_8f8f_c85b7619e923row0_col4 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_b63b6f46_9e23_11eb_8f8f_c85b7619e923row0_col5 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_b63b6f46_9e23_11eb_8f8f_c85b7619e923row0_col6 {
#             background-color:  #f7b79b;
#             color:  #000000;
# ...

# %%
df_for_dm.drop(['Closeness_cent','Degree_Cent','Eigenvector_cent','Total_Impact_Ratio'],axis=1,inplace=True)

# %%
corr = df_for_dm.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d89da04a_9e23_11eb_a247_c85b7619e923row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d89da04a_9e23_11eb_a247_c85b7619e923row0_col1 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_d89da04a_9e23_11eb_a247_c85b7619e923row0_col2 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_d89da04a_9e23_11eb_a247_c85b7619e923row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d89da04a_9e23_11eb_a247_c85b7619e923row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d89da04a_9e23_11eb_a247_c85b7619e923row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d89da04a_9e23_11eb_a247_c85b7619e923row2_col0 {
#             background-color:  #ebd3c6;
#             color:  #000000;
# ...
